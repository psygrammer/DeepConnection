# %% [markdown]
# # Chatper 2. OpenAI Gym

# %% [markdown]
# ---------------------

# %%
D_DISPLAY = True

# %%
import gym

# %%
env = gym.make("Taxi-v2")

# %%
observation = env.reset()
for _ in range(1000):
    if D_DISPLAY :
        env.render()
    action = env.action_space.sample() # your agent here (this takes random actions)
    observation, reward, done, info = env.step(action)
env.close()

# %% [markdown]
# -------------------------

# %% [markdown]
# ## 01_agent_anatomy.py

# %%
import random


class Environment:
    def __init__(self):
        self.steps_left = 10

    def get_observation(self):
        return [0.0, 0.0, 0.0]

    def get_actions(self):
        return [0, 1]

    def is_done(self):
        return self.steps_left == 0

    def action(self, action):
        if self.is_done():
            raise Exception("Game is over")
        self.steps_left -= 1
        return random.random()


class Agent:
    def __init__(self):
        self.total_reward = 0.0

    def step(self, env):
        current_obs = env.get_observation()
        actions = env.get_actions()
        reward = env.action(random.choice(actions))
        self.total_reward += reward


if __name__ == "__main__":
    env = Environment()
    agent = Agent()

    while not env.is_done():
        agent.step(env)

    print("Total reward got: %.4f" % agent.total_reward)
# Out:
# Total reward got: 4.8757

# %% [markdown]
# ------------------------

# %% [markdown]
# ## 02_cartpole_random.py

# %%
import gym

if __name__ == "__main__":
    env = gym.make("CartPole-v0")

    total_reward = 0.0
    total_steps = 0
    obs = env.reset()

    while True:
        if D_DISPLAY :
            env.render()
        action = env.action_space.sample()
        obs, reward, done, _ = env.step(action)
        total_reward += reward
        total_steps += 1
        if done:
            break

    print("Episode done in %d steps, total reward %.2f" % (total_steps, total_reward))

env.close()

# %% [markdown]
# --------------------

# %%
03_random_actionwrapper.py

# %%
import gym

# %%
env = gym.make('CartPole-v0')
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
for i_episode in range(20):
    observation = env.reset()
    for t in range(100):
        if D_DISPLAY :
            env.render()
        print(observation)
        action = env.action_space.sample()
        observation, reward, done, info = env.step(action)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            break
            
env.close()
# Out:
# [ 0.04876267 -0.01310186 -0.00881858  0.0021737 ]
# [ 0.04850064 -0.20809624 -0.00877511  0.29206126]
# [ 0.04433871 -0.01285028 -0.00293388 -0.00337625]
# [ 0.04408171  0.18231363 -0.00300141 -0.29698341]
# [ 0.04772798 -0.01276541 -0.00894108 -0.00524859]
# [ 0.04747267  0.18248362 -0.00904605 -0.30073907]
# [ 0.05112234  0.37773333 -0.01506083 -0.59626115]
# [ 0.05867701  0.57306278 -0.02698605 -0.89364981]
# [ 0.07013826  0.76854012 -0.04485905 -1.19469201]
# [ 0.08550907  0.96421332 -0.06875289 -1.50109067]
# [ 0.10479333  1.16009952 -0.0987747  -1.81442321]
# [ 0.12799532  1.35617259 -0.13506317 -2.13609182]
# [ 0.15511878  1.16262154 -0.177785   -1.88799724]
# Episode finished after 13 timesteps
# [ 0.00279351  0.00606723  0.02925401 -0.02245325]
# [ 0.00291486  0.20075771  0.02880494 -0.30576455]
# [ 0.00693001  0.00523737  0.02268965 -0.00413823]
# [ 0.00703476 -0.19020251  0.02260689  0.29561632]
# [ 0.00323071 -0.38563933  0.02851921  0.5953425 ]
# [-0.00448208 -0.58114858  0.04042606  0.89687063]
# [-0.01610505 -0.77679457  0.05836348  1.20198187]
# [-0.03164094 -0.58247389  0.08240311  0.92814627]
# [-0.04329042 -0.77860588  0.10096604  1.24554508]
# [-0.05886254 -0.58491354  0.12587694  0.98611981]
# [-0.07056081 -0.39168158  0.14559934  0.73547534]
# [-0.07839444 -0.58848257  0.16030884  1.07020845]
# [-0.09016409 -0.78531906  0.18171301  1.40860663]
# Episode finished after 13 timesteps
# [0.0242517  0.04199449 0.03745835 0.01631687]
# [ 0.02509159  0.23655978  0.03778469 -0.26431616]
# [ 0.02982278  0.43112262  0.03249836 -0.54484605]
# [ 0.03844524  0.6257732   0.02160144 -0.82711491]
# [ 0.0509607   0.43036263  0.00505914 -0.52771712]
# [ 0.05956795  0.62541304 -0.0054952  -0.81880161]
# [ 0.07207621  0.43036673 -0.02187123 -0.52785214]
# [ 0.08068355  0.62578947 -0.03242827 -0.82734576]
# [ 0.09319934  0.43112558 -0.04897519 -0.54503569]
# [ 0.10182185  0.62690026 -0.0598759  -0.85273856]
# [ 0.11435986  0.82278509 -0.07693067 -1.16363226]
# [ 0.13081556  0.62874443 -0.10020332 -0.89602745]
# [ 0.14339045  0.82507173 -0.11812387 -1.21845169]
# [ 0.15989188  1.02150172 -0.1424929  -1.54569115]
# [ 0.18032191  0.82834979 -0.17340673 -1.30065092]
# [ 0.19688891  0.63579985 -0.19941974 -1.06688407]
# Episode finished after 16 timesteps
# [ 0.03999633 -0.02490165 -0.02329394 -0.03103439]
# [ 0.0394983  -0.21968194 -0.02391463  0.25420898]
# [ 0.03510466 -0.02422683 -0.01883045 -0.04592007]
# [ 0.03462012  0.17116    -0.01974885 -0.34448419]
# [ 0.03804332  0.36655725 -0.02663854 -0.64332869]
# [ 0.04537447  0.56204015 -0.03950511 -0.94427981]
# [ 0.05661527  0.75767139 -0.05839071 -1.2491092 ]
# [ 0.0717687   0.56334453 -0.08337289 -0.9752728 ]
# [ 0.08303559  0.75947984 -0.10287835 -1.29293709]
# [ 0.09822518  0.5658049  -0.12873709 -1.03415361]
# [ 0.10954128  0.76238177 -0.14942016 -1.3643231 ]
# [ 0.12478892  0.95902568 -0.17670662 -1.69976857]
# Episode finished after 12 timesteps
# [ 0.04522903 -0.0124464   0.03808584 -0.01422519]
# [ 0.0449801   0.18210924  0.03780134 -0.29465249]
# [ 0.04862229 -0.01353067  0.03190829  0.00970869]
# [ 0.04835167  0.18111949  0.03210246 -0.27273848]
# [ 0.05197406 -0.01444547  0.02664769  0.02989432]
# [ 0.05168515 -0.20993923  0.02724558  0.33086434]
# [ 0.04748637 -0.01521549  0.03386286  0.04689634]
# [ 0.04718206  0.17940494  0.03480079 -0.23491316]
# [ 0.05077016 -0.01619651  0.03010253  0.06854072]
# [ 0.05044623  0.17848122  0.03147334 -0.21449477]
# [ 0.05401585 -0.01707622  0.02718345  0.08794775]
# [ 0.05367433  0.17764575  0.0289424  -0.19603635]
# [ 0.05722724 -0.01787798  0.02502167  0.1056343 ]
# [ 0.05686968 -0.2133494   0.02713436  0.40610526]
# [ 0.0526027  -0.40884541  0.03525646  0.70721785]
# [ 0.04442579 -0.60443759  0.04940082  1.01078705]
# [ 0.03233704 -0.80018273  0.06961656  1.31856448]
# Episode finished after 12 timesteps
# [ 0.04425402  0.03394262 -0.00427609  0.03664266]
# [ 0.04493288 -0.16111775 -0.00354324  0.32797337]
# [0.04171052 0.03405446 0.00301623 0.03417518]
# [ 0.04239161 -0.16111061  0.00369973  0.32780823]
# [0.0391694  0.03395847 0.0102559  0.03629432]
# [ 0.03984857  0.22893186  0.01098179 -0.2531352 ]
# [0.04442721 0.03365484 0.00591908 0.04299125]
# [ 0.0451003  -0.16155149  0.00677891  0.33753582]
# [ 0.04186927 -0.35676925  0.01352962  0.63234871]
# [ 0.03473389 -0.16183864  0.0261766   0.34395715]
# [ 0.03149711 -0.35732301  0.03305574  0.64477829]
# [ 0.02435065 -0.55288965  0.04595131  0.94768461]
# [ 0.01329286 -0.35841555  0.064905    0.66978632]
# [ 0.00612455 -0.1642532   0.07830072  0.39822471]
# [0.00283949 0.02967567 0.08626522 0.13121958]
# [ 0.003433    0.22346277  0.08888961 -0.13304963]
# [0.00790226 0.02718742 0.08622862 0.18630016]
# [ 0.008446    0.2209766   0.08995462 -0.07798379]
# [0.01286554 0.02468795 0.08839495 0.24166973]
# [ 0.01335929 -0.17157817  0.09322834  0.56087378]
# [ 0.00992773 -0.36787637  0.10444582  0.88141185]
# [ 0.0025702  -0.56425016  0.12207405  1.20501859]
# [-0.0087148  -0.37089886  0.14617442  0.95295067]
# [-0.01613278 -0.17801391  0.16523344  0.70953117]
# [-0.01969305  0.01448098  0.17942406  0.4730794 ]
# [-0.01940343 -0.18266092  0.18888565  0.81651315]
# [-0.02305665  0.00944267  0.20521591  0.58868563]
# Episode finished after 27 timesteps
# [ 0.01454744  0.03542772  0.01354537 -0.04422395]
# [ 0.01525599 -0.15988582  0.01266089  0.2527017 ]
# [ 0.01205828  0.03505308  0.01771492 -0.035961  ]
# [ 0.01275934  0.22991657  0.0169957  -0.32300247]
# [ 0.01735767  0.42479244  0.01053565 -0.61027756]
# [ 0.02585352  0.61976555 -0.0016699  -0.89962357]
# [ 0.03824883  0.81491009 -0.01966237 -1.19283092]
# [ 0.05454703  1.01028114 -0.04351899 -1.49161121]
# [ 0.07475266  0.81571504 -0.07335121 -1.21282892]
# [ 0.09106696  0.62161239 -0.09760779 -0.94400379]
# [ 0.1034992   0.81790417 -0.11648787 -1.26569113]
# [ 0.11985729  1.01430589 -0.14180169 -1.5924672 ]
# [ 0.14014341  1.21079751 -0.17365103 -1.92579647]
# Episode finished after 13 timesteps
# [ 0.00928083  0.03591722 -0.01354678 -0.01643549]
# [ 0.00999917  0.2312308  -0.01387548 -0.31336162]
# [ 0.01462379  0.42654764 -0.02014272 -0.61038793]
# [ 0.02315474  0.62194527 -0.03235048 -0.90934648]
# [ 0.03559365  0.81748979 -0.05053741 -1.21201916]
# [ 0.05194344  1.01322634 -0.07477779 -1.52010081]
# [ 0.07220797  1.20916828 -0.1051798  -1.83515655]
# [ 0.09639133  1.01535502 -0.14188294 -1.57690915]
# [ 0.11669844  0.82218027 -0.17342112 -1.33163246]
# [ 0.13314204  0.62961687 -0.20005377 -1.09785061]
# Episode finished after 10 timesteps
# [-0.03468878  0.03106038 -0.03307199  0.04344039]
# [-0.03406757  0.22664058 -0.03220318 -0.25949087]
# [-0.02953476  0.42220711 -0.037393   -0.56215466]
# [-0.02109062  0.6178333  -0.04863609 -0.8663798 ]
# [-0.00873395  0.42340578 -0.06596369 -0.58937677]
# [-2.65838860e-04  6.19386362e-01 -7.77512230e-02 -9.02087571e-01]
# [ 0.01212189  0.81547066 -0.09579297 -1.21816127]
# [ 0.0284313   1.01168822 -0.1201562  -1.53925831]
# [ 0.04866507  1.20803335 -0.15094137 -1.86689349]
# [ 0.07282573  1.40445103 -0.18827924 -2.20237855]
# Episode finished after 10 timesteps
# [-0.00522061 -0.02710653 -0.02309383 -0.01244357]
# [-0.00576274  0.16833887 -0.0233427  -0.31232249]
# [-0.00239597 -0.02644289 -0.02958915 -0.02709157]
# [-0.00292482 -0.22112829 -0.03013098  0.25611076]
# [-0.00734739 -0.41580738 -0.02500877  0.53913968]
# [-0.01566354 -0.610569   -0.01422598  0.82383894]
# [-0.02787492 -0.41525536  0.0022508   0.52671584]
# [-0.03618002 -0.22016515  0.01278512  0.234743  ]
# [-0.04058333 -0.41546742  0.01747998  0.53143118]
# [-0.04889268 -0.22059565  0.0281086   0.24430703]
# [-0.05330459 -0.41610757  0.03299474  0.5457219 ]
# [-0.06162674 -0.61167721  0.04390918  0.8486154 ]
# [-0.07386028 -0.41718075  0.06088149  0.57005706]
# [-0.0822039  -0.61310132  0.07228263  0.88128154]
# [-0.09446593 -0.41903174  0.08990826  0.61216991]
# [-0.10284656 -0.61528757  0.10215166  0.93176207]
# [-0.11515231 -0.4216814   0.1207869   0.67284708]
# [-0.12358594 -0.61825676  0.13424384  1.00098685]
# [-0.13595108 -0.81489234  0.15426358  1.33263573]
# [-0.15224892 -1.01158572  0.1809163   1.66934601]
# Episode finished after 20 timesteps
# [ 0.02071792  0.00466214  0.03736117 -0.04955492]
# [ 0.02081116  0.199229    0.03637007 -0.33021992]
# [ 0.02479574  0.39381485  0.02976567 -0.61121523]
# [ 0.03267204  0.5885084   0.01754137 -0.89437638]
# [ 4.44422044e-02  3.93153019e-01 -3.46162576e-04 -5.96231492e-01]
# [ 0.05230526  0.58827981 -0.01227079 -0.88902344]
# [ 0.06407086  0.39332651 -0.03005126 -0.60022302]
# [ 0.07193739  0.58885571 -0.04205572 -0.90221813]
# [ 0.08371451  0.39432796 -0.06010008 -0.62304525]
# [ 0.09160106  0.20009438 -0.07256099 -0.3498797 ]
# [ 0.09560295  0.00607537 -0.07955858 -0.0809312 ]
# [ 0.09572446 -0.1878213  -0.08117721  0.18562827]
# [ 0.09196803  0.00836263 -0.07746464 -0.13151846]
# [ 0.09213529  0.20450384 -0.08009501 -0.4475998 ]
# [ 0.09622536  0.40066204 -0.08904701 -0.76441658]
# [ 0.1042386   0.20687186 -0.10433534 -0.50102825]
# [ 0.10837604  0.4032979  -0.1143559  -0.82468403]
# [ 0.116442    0.20991025 -0.13084958 -0.57004463]
# [ 0.1206402   0.01684266 -0.14225048 -0.32127903]
# [ 0.12097706  0.21367353 -0.14867606 -0.65522393]
# [ 0.12525053  0.41051835 -0.16178054 -0.99078369]
# [ 0.13346089  0.60739218 -0.18159621 -1.32959455]
# [ 0.14560874  0.41496546 -0.2081881  -1.09879701]
# Episode finished after 23 timesteps
# [-0.03836762  0.00351258  0.04380054 -0.01856182]
# [-0.03829737  0.1979799   0.0434293  -0.2971098 ]
# [-0.03433777  0.00226663  0.03748711  0.00894751]
# [-0.03429244  0.19683147  0.03766606 -0.27167608]
# [-0.03035581  0.00119285  0.03223253  0.0326449 ]
# [-0.03033195  0.1958381   0.03288543 -0.2496966 ]
# [-0.02641519  0.39047537  0.0278915  -0.53182808]
# [-0.01860568  0.19497245  0.01725494 -0.23048871]
# [-0.01470623 -0.00039177  0.01264516  0.06758669]
# [-0.01471407  0.19454663  0.0139969  -0.22107995]
# [-0.01082313  0.38946574  0.0095753  -0.50931503]
# [-0.00303382  0.19421021 -0.000611   -0.21363006]
# [ 0.00085038  0.38934089 -0.0048836  -0.50650566]
# [ 0.0086372   0.58453132 -0.01501372 -0.80072358]
# [ 0.02032783  0.77985594 -0.03102819 -1.09809136]
# [ 0.03592495  0.97537233 -0.05299001 -1.40034561]
# [ 0.05543239  1.17111131 -0.08099693 -1.70911372]
# [ 0.07885462  1.36706537 -0.1151792  -2.02586824]
# [ 0.10619593  1.17330777 -0.15569657 -1.7709454 ]
# [ 0.12966208  0.98024804 -0.19111547 -1.53044882]
# Episode finished after 20 timesteps

# %% [markdown]
# -----------------------

# %% [markdown]
# ## 04_cartpole_random_monitor.py

# %%
import gym

env = gym.make("CartPole-v0")

total_reward = 0.0
total_steps = 0
obs = env.reset()

while True:
    if D_DISPLAY :
        env.render()
    action = env.action_space.sample()
    obs, reward, done, _ = env.step(action)
    total_reward += reward
    total_steps += 1
    if done:
        break

print("Episode done in %d steps, total reward %.2f" % (total_steps, total_reward))
env.close()
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Episode done in 20 steps, total reward 20.00

# %% [markdown]
# --------------------

# %%
import gym
env = gym.make("CartPole-v0")
env = gym.wrappers.Monitor(env, "recording")

total_reward = 0.0
total_steps = 0
obs = env.reset()

while True:
    action = env.action_space.sample()
    obs, reward, done, _ = env.step(action)
    total_reward += reward
    total_steps += 1
    if done:
        break

print("Episode done in %d steps, total reward %.2f" % (total_steps, total_reward))
env.close()
env.env.close()
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Episode done in 12 steps, total reward 12.00

# %%
# !ls
# Out:
# 00_ch02.ipynb	       03_random_actionwrapper.py     test.py
# 01_agent_anatomy.py    04_cartpole_random_monitor.py
# 02_cartpole_random.py  recording

# %%
# !ls recording/
# Out:
# openaigym.episode_batch.0.1333.stats.json
# openaigym.manifest.0.1333.manifest.json
# openaigym.video.0.1333.video000000.meta.json
# openaigym.video.0.1333.video000000.mp4

# %% [markdown]
# -----------------------

# %% [markdown]
# # 참고자료

# %% [markdown]
# * [1] 주교재 : Deep Reinforcement Learning Hands-On - https://www.packtpub.com/big-data-and-business-intelligence/deep-reinforcement-learning-hands
# * [2] 주교재 공식 깃헙 저장소 - https://github.com/PacktPublishing/Deep-Reinforcement-Learning-Hands-On
# * [3] OpenAI Gym 공식 페이지 - https://gym.openai.com/
